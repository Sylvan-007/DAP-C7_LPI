# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objs as go

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_csv("C:/Users/sylva/OneDrive/Desktop/Sylva/AZUBI AFRICA/Demo/Kawabanga/DAP-C7_LPI/Datasets/2018-dataset.csv")

# %%
data.tail(60)
# Out:
#      Unnamed: 0                                    Company Name  \
# 466         466                            Bounce (Metro Bikes)
# 467         467                         Technology 9 Labs (T9L)
# 468         468                                        Goals101
# 469         469                              Satya MicroCapital
# 470         470          Ummeed Housing Finance Private Limited
# 471         471                                       StockEdge
# 472         472                                       Sequretek
# 473         473                Avenues Payments India Pvt. Ltd.
# 474         474                                           Qbera
# 475         475                                    Urban Ladder
# 476         476   Planet11 eCommerce Solutions India (Avenue11)
# 477         477                                      DailyNinja
# 478         478                                  Iba Halal Care
# 479         479                                      Knocksense
# ...
